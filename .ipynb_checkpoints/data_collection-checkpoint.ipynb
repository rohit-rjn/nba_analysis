# %%
import pandas as pd
from nba_py import team
from nba_py import game
from nba_py import Scoreboard

# %%
df = game.Boxscore(game_id='0021800944', season='2018-19', season_type='Regular Season', range_type='0', start_period='0', end_period='0', start_range='0', end_range='0')
df = df.team_starter_bench_stats()
df.head()
# Out:
#       GAME_ID     TEAM_ID      TEAM_NAME TEAM_ABBREVIATION  TEAM_CITY  \
# 0  0021800944  1610612757  Trail Blazers               POR   Portland
# 1  0021800944  1610612757  Trail Blazers               POR   Portland
# 2  0021800944  1610612766        Hornets               CHA  Charlotte
# 3  0021800944  1610612766        Hornets               CHA  Charlotte
#
#   STARTERS_BENCH     MIN  FGM  FGA  FG_PCT  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0       Starters  152:07   28   63   0.444  ...   0.923     9    25   34   21
# 1          Bench   87:53   15   33   0.455  ...   0.900     4    10   14    5
# 2       Starters  147:25   17   51   0.333  ...   0.909     3    11   14   17
# 3          Bench   92:35   20   32   0.625  ...   0.833     1    20   21    8
#
#    STL  BLK  TO  PF  PTS
# 0    6    2  11  14   75
# 1    3    1   0   9   43
# 2    7    4   5  11   51
# 3    0    1   7  10   57
#
# [4 rows x 25 columns]

# %%
df.to_csv('boxscore_team_stats.csv')
df.head()
# Out:
#       GAME_ID     TEAM_ID      TEAM_NAME TEAM_ABBREVIATION  TEAM_CITY     MIN  \
# 0  0021800944  1610612757  Trail Blazers               POR   Portland  240:00
# 1  0021800944  1610612766        Hornets               CHA  Charlotte  240:00
#
#    FGM  FGA  FG_PCT  FG3M  ...  OREB  DREB  REB  AST  STL  BLK  TO  PF  PTS  \
# 0   43   96   0.448    11  ...    13    35   48   26    9    3  11  23  118
# 1   37   83   0.446    14  ...     4    31   35   25    7    5  12  21  108
#
#    PLUS_MINUS
# 0        10.0
# 1       -10.0
#
# [2 rows x 25 columns]

# %%
df = game.BoxscoreSummary(game_id='0021800155', season='2018-19', season_type='Regular Season', range_type='0', start_period='0', end_period='0', start_range='0', end_range='0')
df = df.line_score()

# %%
df.to_csv('boxscoresumm_line_score.csv')
df.head()
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID     TEAM_ID  \
# 0  2018-11-07T00:00:00              3  0021800155  1610612737
# 1  2018-11-07T00:00:00              3  0021800155  1610612752
#
#   TEAM_ABBREVIATION TEAM_CITY_NAME TEAM_NICKNAME TEAM_WINS_LOSSES  PTS_QTR1  \
# 0               ATL        Atlanta         Hawks              3-8        26
# 1               NYK       New York        Knicks              4-8        26
#
#    PTS_QTR2  ...  PTS_OT2  PTS_OT3  PTS_OT4  PTS_OT5  PTS_OT6  PTS_OT7  \
# 0        29  ...        0        0        0        0        0        0
# 1        26  ...        0        0        0        0        0        0
#
#    PTS_OT8  PTS_OT9  PTS_OT10  PTS
# 0        0        0         0  107
# 1        0        0         0  112
#
# [2 rows x 23 columns]

# %%
df = game.BoxscoreAdvanced(game_id='0021800155', season='2018-19', season_type='Regular Season', range_type='0', start_period='0', end_period='0', start_range='0', end_range='0')
df = df.sql_team_advanced()

# %%
df.to_csv('boxscoreadv_team.csv')
df.head()
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION TEAM_CITY     MIN  \
# 0  0021800155  1610612752    Knicks               NYK  New York  240:00
# 1  0021800155  1610612737     Hawks               ATL   Atlanta  240:00
#
#    E_OFF_RATING  OFF_RATING  E_DEF_RATING  DEF_RATING  ...  TM_TOV_PCT  \
# 0         107.0       106.7         100.2       102.9  ...        17.1
# 1         100.2       102.9         107.0       106.7  ...        16.3
#
#    EFG_PCT  TS_PCT  USG_PCT  E_USG_PCT  E_PACE   PACE  PACE_PER40  POSS    PIE
# 0    0.513   0.573      1.0      0.199  105.72  104.5       87.08   105  0.517
# 1    0.462   0.511      1.0      0.195  105.72  104.5       87.08   104  0.483
#
# [2 rows x 29 columns]

# %%
df = game.BoxscoreFourFactors(game_id='0021800155', season='2018-19', season_type='Regular Season', range_type='0', start_period='0', end_period='0', start_range='0', end_range='0')
df = df.sql_team_four_factors()

# %%
df.to_csv('boxscorefourfactor_team.csv')
df.head()
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION TEAM_CITY     MIN  \
# 0  0021800155  1610612752    Knicks               NYK  New York  240:00
# 1  0021800155  1610612737     Hawks               ATL   Atlanta  240:00
#
#    EFG_PCT  FTA_RATE  TM_TOV_PCT  OREB_PCT  OPP_EFG_PCT  OPP_FTA_RATE  \
# 0    0.513     0.610       0.172     0.229        0.462         0.315
# 1    0.462     0.315       0.159     0.259        0.513         0.610
#
#    OPP_TOV_PCT  OPP_OREB_PCT
# 0        0.159         0.310
# 1        0.172         0.333

# %%
df = game.HustleStats(game_id='0021800155')
df = df.hustle_stats_available()
df.head()
# Out:
#       GAME_ID  HUSTLE_STATUS
# 0  0021800155              1

# %%
df.to_csv('hussle_stats.csv')

# %%
df = game.PlayByPlay(game_id='0021800155', start_period='0', end_period='0')
df = df.info()
df.head()
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0  0021800155         2            12                   0       1
# 1  0021800155         4            10                   0       1
# 2  0021800155         7             1                 101       1
# 3  0021800155         9             5                   4       1
# 4  0021800155        10             1                 108       1
#
#   WCTIMESTRING PCTIMESTRING                               HOMEDESCRIPTION  \
# 0      7:41 PM        12:00                                          None
# 1      7:41 PM        12:00  Jump Ball Len vs. Robinson: Tip to Ntilikina
# 2      7:41 PM        11:41                                          None
# 3      7:41 PM        11:38              Young Traveling Turnover (P1.T1)
# 4      7:42 PM        11:31                                          None
#
#   NEUTRALDESCRIPTION                                 VISITORDESCRIPTION  \
# ...

# %%
df = game.BoxscoreSummary(game_id='0021800944', season='2018-19', season_type='Regular Season', range_type='0', start_period='0', end_period='0', start_range='0', end_range='0')
df = df.season_series()
df.head()
# Out:
#       GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID        GAME_DATE_EST  \
# 0  0021800944    1610612766       1610612757  2019-03-03T00:00:00
#
#    HOME_TEAM_WINS  HOME_TEAM_LOSSES SERIES_LEADER
# 0               0                 2      Portland

# %%
df = Scoreboard(month=11, day=6, year=2017, league_id='00', offset=0)
df = df.series_standings()
df.head()
# Out:
#       GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID        GAME_DATE_EST  \
# 0  0021700146    1610612737       1610612738  2017-11-06T00:00:00
# 1  0021700148    1610612744       1610612748  2017-11-06T00:00:00
# 2  0021700147    1610612756       1610612751  2017-11-06T00:00:00
#
#    HOME_TEAM_WINS  HOME_TEAM_LOSSES SERIES_LEADER
# 0               1                 3        Boston
# 1               2                 0  Golden State
# 2               1                 1          Tied

# %%
df = team.TeamLastNGamesSplits(team_id='1610612737', measure_type='Base', per_mode='PerGame', 
                               plus_minus='N', pace_adjust='N', rank='N', league_id='00', 
                               season='2017-18', season_type='Regular Season', po_round='0', 
                               outcome='', location='', month='0', season_segment='', date_from='', 
                               date_to='', opponent_team_id='0', vs_conference='', vs_division='', 
                               game_segment='', period='0', shot_clock_range='', last_n_games='0')
df = df.last20()
df.head()
# Out:
#        GROUP_SET    GROUP_VALUE  GP  W   L  W_PCT   MIN   FGM   FGA  FG_PCT  \
# 0  Last 20 Games  Last 20 Games  20  5  15   0.25  48.0  38.3  87.0    0.44
#
#    ...  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# 0  ...         1         1         1          1        1         1         1
#
#    PLUS_MINUS_RANK  CFID       CFPARAMS
# 0                1   161  Last 20 Games
#
# [1 rows x 56 columns]

# %%
df = team.TeamGeneralSplits(team_id='1610612737', measure_type='Base', per_mode='PerGame', plus_minus='N', pace_adjust='N',
                            rank='N', league_id='00', season='2017-18', season_type='Regular Season', 
                            po_round='0', outcome='', location='', month='0', season_segment='', 
                            date_from='', date_to='', opponent_team_id='0', vs_conference='', vs_division='', 
                            game_segment='', period='0', shot_clock_range='', last_n_games='0')
df = df.wins_losses()
df.head()
# Out:
#      GROUP_SET GROUP_VALUE GAME_RESULT  GP   W   L  W_PCT   MIN   FGM   FGA  \
# 0  Wins/Losses        Wins        Wins  24  24   0    1.0  48.0  41.1  86.2
# 1  Wins/Losses      Losses      Losses  58   0  58    0.0  48.1  36.9  85.3
#
#    ...  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# 0  ...         1         2         1          2        2         2         1
# 1  ...         2         1         2          1        1         1         2
#
#    PLUS_MINUS_RANK  CFID  CFPARAMS
# 0                1   157      Wins
# 1                2   157    Losses
#
# [2 rows x 57 columns]

# %%
df = team.TeamPassTracking(team_id='1610612737', measure_type='Base', per_mode='PerGame', plus_minus='N', pace_adjust='N', rank='N', 
                           league_id='00', season='2017-18', season_type='Regular Season', po_round='0', 
                           outcome='', location='', month='0', season_segment='', date_from='', date_to='', 
                           opponent_team_id='0', vs_conference='', vs_division='', game_segment='', period='0',
                           shot_clock_range='', last_n_games='0')
df = df.passes_recieved()
df.head()
# Out:
#       TEAM_ID      TEAM_NAME PASS_TYPE   G         PASS_FROM  \
# 0  1610612737  Atlanta Hawks      made  66  Schroder, Dennis
# 1  1610612737  Atlanta Hawks      made  64    Bazemore, Kent
# 2  1610612737  Atlanta Hawks      made  73     Collins, John
# 3  1610612737  Atlanta Hawks      made  46   Ilyasova, Ersan
# 4  1610612737  Atlanta Hawks      made  61   Dedmon, Dewayne
#
#    PASS_TEAMMATE_PLAYER_ID  FREQUENCY   PASS   AST   FGM    FGA  FG_PCT  FG2M  \
# 0                   203471      0.155  62.70  6.21  7.17  17.73   0.404  4.45
# 1                   203145      0.089  37.22  3.48  4.83  10.53   0.458  3.72
# 2                  1628381      0.099  36.27  1.36  2.48   6.15   0.403  1.75
# 3                   101141      0.058  33.80  1.11  2.30   6.37   0.362  1.70
# 4                   203473      0.073  31.75  1.39  2.79   6.39   0.436  2.05
#
#    FG2A  FG2_PCT  FG3M  FG3A  FG3_PCT
# 0  9.89    0.450  2.71  7.83    0.346
# 1  7.63    0.488  1.11  2.91    0.382
# ...
