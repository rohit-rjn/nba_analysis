# %%
import pandas as pd
from nba_py import team
from nba_py import game
from nba_py import Scoreboard
from datetime import date, timedelta

# %% [markdown]
# ### Part 1- Data Wrangling
#
# 1) Downloading data from NBA.stats for the season 2018-2019
# 2) Coverting data into different DF

# %%
# Date Generator - Date from 

date_list = []
start_date = date(2018, 10, 16)
end_date = date(2019, 4, 10)
delta = timedelta(days=1)
while start_date <= end_date:
    print (start_date.strftime("%Y-%m-%d"))
    date_list.append(start_date)
    start_date += delta
# Out:
# 2018-01-01
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-06
# 2018-01-07
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-13
# 2018-01-14
# 2018-01-15
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-20
# 2018-01-21
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-27
# 2018-01-28
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-03
# 2018-02-04
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-10
# 2018-02-11
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-17
# 2018-02-18
# 2018-02-19
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-24
# 2018-02-25
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-03
# 2018-03-04
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-10
# 2018-03-11
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-17
# ...

# %%
df = Scoreboard(month=11, day=7, year=2018, league_id='00', offset=0)

# %%
df_data = df.line_score()

# %%
print(df_data)
# Out:
#           GAME_DATE_EST  GAME_SEQUENCE     GAME_ID     TEAM_ID  \
# 0   2018-11-07T00:00:00              1  0021800153  1610612760
# 1   2018-11-07T00:00:00              1  0021800153  1610612739
# 2   2018-11-07T00:00:00              2  0021800154  1610612765
# 3   2018-11-07T00:00:00              2  0021800154  1610612753
# 4   2018-11-07T00:00:00              3  0021800155  1610612752
# 5   2018-11-07T00:00:00              3  0021800155  1610612737
# 6   2018-11-07T00:00:00              4  0021800156  1610612759
# 7   2018-11-07T00:00:00              4  0021800156  1610612748
# 8   2018-11-07T00:00:00              5  0021800157  1610612755
# 9   2018-11-07T00:00:00              5  0021800157  1610612754
# 10  2018-11-07T00:00:00              6  0021800158  1610612743
# 11  2018-11-07T00:00:00              6  0021800158  1610612763
# 12  2018-11-07T00:00:00              7  0021800159  1610612741
# 13  2018-11-07T00:00:00              7  0021800159  1610612740
# ...
