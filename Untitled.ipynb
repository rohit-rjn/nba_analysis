# %%
import urllib.request 
import time
import json
import requests

# %%
time.sleep(3)

# %%
url = "https://stats.nba.com/stats/scoreboardV2?DayOffset=0&LeagueID=00&gameDate=03/03/2019"
#req = urllib.request.Request(url)
#req.set_proxy('localhost:8889', 'http') 
#response = urllib.request.urlopen(req)
proxies = {
"http": "http://ip:port",
"https": "http://ip:port",
}

req = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\Users\rohit\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# C:\Users\rohit\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\Users\rohit\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...
